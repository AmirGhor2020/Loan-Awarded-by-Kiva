# %% [markdown]
# # Visualizing Loans Awarded by Kiva
#
# In this project I'll visualize insights using a dataset from <a href = "https://www.kaggle.com/fkosmowski/kivadhsv1" target = "_blank">Kaggle</a>. The dataset contains information about loans awarded by the non-profit <a href = "https://www.kiva.org/" target = "_blank">Kiva</a>.
#
# Using Seaborn, I'll explore the <strong>average loan amount by country</strong> using <strong>aggregated bar charts</strong>. You'll also visualize <strong>the distribution of loan amounts by project type and gender</strong> using <strong>box plots and violin plots</strong>.
#
# <!-- Some of the steps below will have  hints that you can access if you need them. Hints will look like this:
# <br>
# <br>
# <details>
# <summary>Hint (click me)</summary>
# <br>
# I'm a hint!
# <br>
# </details> -->

# %% [markdown]
# <!-- **A Note On `plt.show()`:** You may be used to displaying your plots using the code `plt.show()`. This IPython Jupyter notebook removes the necessity of calling `plt.show()` after each plot. You should be able to render your Seaborn plots simply by running the cell with the code for your plot. If you have issues rendering your plot you can try adding `plt.show()` to a cell. -->

# %% [markdown]
# ## Step 1: Import Necessary Python Modules
# Importing the modules that I'll be using in this project:
# - `from matplotlib import pyplot as plt`
# - `import pandas as pd`
# - `import seaborn as sns`

# %%
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Step 2: Ingest The Data
# <!-- Load **kiva_data.csv** into a DataFrame called `df`. Then, quickly inspect the DataFrame using `.head()`.
# <br>
# <br>
# <details>
# <summary>Hint</summary>
# <br>
# Use `pd.read_csv()`.
# <br>
# </details> -->

# %%
df = pd.read_csv('kiva_data.csv')
df.head()
# Out:
#    loan_amount               activity   country  gender
# 0          625  Food Production/Sales  Pakistan  female
# 1          250  Food Production/Sales  Pakistan  female
# 2          400  Food Production/Sales  Pakistan  female
# 3          400  Food Production/Sales  Pakistan  female
# 4          500  Food Production/Sales  Pakistan  female

# %% [markdown]
# ## Step 3: Examine The Data
#
# <!-- If you would like, you can examine the raw CSV file on your local machine. You can find **kiva_data.csv** in the project download folder. -->
#
# ### Overview of the dataset:
#
# Each entry (row) in the dataset represents a loan that Kiva awarded to a particular project. The `loan_amount` column shows the amount (in U.S. dollars) awarded to the project. The `activity` column has the category type that the project falls under. The `country` column is the country where the project is located. The `gender` column represents the gender of the primary person who applied for the loan.
#
#
# Print the first 25 rows of `df` using `.head()`

# %%
df.head(25)
# Out:
#     loan_amount               activity   country  gender
# 0           625  Food Production/Sales  Pakistan  female
# 1           250  Food Production/Sales  Pakistan  female
# 2           400  Food Production/Sales  Pakistan  female
# 3           400  Food Production/Sales  Pakistan  female
# 4           500  Food Production/Sales  Pakistan  female
# 5           500  Food Production/Sales  Pakistan  female
# 6           400  Food Production/Sales  Pakistan  female
# 7           500  Food Production/Sales  Pakistan  female
# 8           400  Food Production/Sales  Pakistan  female
# 9           450  Food Production/Sales  Pakistan  female
# 10          250  Food Production/Sales  Pakistan  female
# 11          300  Food Production/Sales  Pakistan  female
# 12          275  Food Production/Sales  Pakistan  female
# 13          425  Food Production/Sales  Pakistan  female
# 14          425  Food Production/Sales  Pakistan  female
# 15          475  Food Production/Sales  Pakistan  female
# 16          225  Food Production/Sales  Pakistan  female
# 17          475  Food Production/Sales  Pakistan  female
# 18          525  Food Production/Sales  Pakistan  female
# 19          425  Food Production/Sales  Pakistan  female
# 20          475  Food Production/Sales  Pakistan  female
# 21          550  Food Production/Sales  Pakistan  female
# 22          450  Food Production/Sales  Pakistan  female
# 23          250  Food Production/Sales  Pakistan  female
# 24          600  Food Production/Sales  Pakistan  female

# %% [markdown]
# ## Step 4: Bar Charts

# %% [markdown]
# Creating a bar plot using Seaborn to visualize the average size of Kiva loans given to projects, by country.
#
# I've set up the figure I'll use to plot my bar plot on. The `f01` variable gives us access to the figure and `ax01` gives us access to the axes.
#
# <!-- Use `sns.barplot()` with the following arguments:
#
# - `data` set to `df`
# - `x` set to `country`
# - `y` set to `loan_amount` -->

# %%
# Creates the figure, note: I'm only using this syntax so that I can modify the y-axis ticks later
f01, ax01 = plt.subplots(figsize=(15, 10))
ax01 = sns.barplot(
    data= df,
    x = "country",
    y = "loan_amount"
)

# %% [markdown]
# ### Adding `$` units

# %%
import matplotlib.ticker as mtick

# Creates the figure
f01, ax01 = plt.subplots(figsize=(15, 10))

# Plot the data
ax01 = sns.barplot(
    data=df,
    x="country",
    y = "loan_amount"
)

# Use part of the code above to format the y-axis ticks below this line
fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
ax01.yaxis.set_major_formatter(tick)

# %% [markdown]
# ## Step 5: Learn More By Using `hue` In My Visualization

# %% [markdown]
# I can visualize even more data on one bar plot by visualizing the loan amount by country, and "nesting" by gender. Add the `hue` parameter to my `sns.barplot()` and set it so that the visualization includes the nested category of gender.
# <!-- <br>
# <br>
# <details>
# <summary>Hint</summary>
# <br>
# Set `hue` equal to the column name `gender`.
# <br>
# </details> -->

# %%
# Creates the figure, I'm only using this syntax so I can modify the y-axis ticks below
f01, ax01 = plt.subplots(figsize=(15, 10))

ax01 = sns.barplot(
    data=df,
    x="country",
    y="loan_amount",
    hue = "gender"
)

fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
ax01.yaxis.set_major_formatter(tick)

# %% [markdown]
# #### Reflection

# %% [markdown]
# On average male recipients receive larger loans from Kiva.<br>
# El Salvador has the least disparity in loan amounts awarded by gender.

# %% [markdown]
# ## Step 6: Styling
#
#
# Set a different color palette using `sns.set_palette()`. I can use any of the Color Brewer qualitative color palettes:
#
# - Set1
# - Set2
# - Set3
# - Pastel1
# - Pastel2
# - Dark2
# - Accent
#
# <!-- You can read more about <a href = "https://seaborn.pydata.org/tutorial/color_palettes.html#qualitative-color-palettes" target = "_blank">qualitative color palettes in the Seaborn documentation.</a> -->
#
#
# Set the plot background style using `sns.set_style()`. I can experiment with:
# - whitegrid
# - darkgrid
# - white
# - dark
#
# Set the title using `ax.set_title("")`.

# %%
# Use Seaborn to create the bar plot
# Creates the figure, I'm only using this syntax so I can modify the y-axis ticks below
f01, ax01 = plt.subplots(figsize=(15, 7))
ax01 = sns.barplot(
    data=df,
    x="country",
    y="loan_amount",
    hue = "gender"
)

ax01.set_title('Average Loan Amounts Given by Kiva, by country, by gender (in $ USD)')

plt.show()

fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
ax01.yaxis.set_major_formatter(tick)

# Set color palette
sns.set_palette("Accent")

# Set style
sns.set_style("darkgrid")

# %% [markdown]
# ## Step 7: Box Plots With Kiva Data
#
# So far I have visualized the average size of loans by country using bar charts; now I am going to make a box plot to compare the distribution of loans by country.

# %% [markdown]
# <!-- We have set up a figure for you to plot on. Use `sns.boxplot()` to compare the distribution of loan amounts by country for the Kiva dataset.    -->
#
# `sns.boxplot()` can be passed the same parameters as `sns.barplot()`.
#
# <!-- **Optional:** You may set a new color palette if you would like to continue using `sns.set_palette()`. -->

# %%
f02, ax02 = plt.subplots(figsize=(16, 10))
ax02 = sns.boxplot(
    data=df,
    x="country",
    y="loan_amount",
#     hue = "gender"
)

# %% [markdown]
# #### Reflection
#
# Kenya's box has the widest distribution of loan amount.<br>
# In Cambodia You would be most likely to receive the largest loan amount.

# %% [markdown]
# ## Step 8: Box Plot by Activity

# %% [markdown]
# Instead of visualizing the loan amount by *country*, use `sns.boxplot()` to plot the loan amount by *activity*.
# <!-- <br>
# <br>
# <details>
# <summary>Hint</summary>
# <br>
# You can use the same code as the box plot above, but the `x` parameter should be set to `"activity"`.
# <br>
# </details>
#
# **Optional:** Set a different plot style and color palette to best visualize this data. -->

# %% [markdown]
# ## Step 9: Violin Plots

# %%
f02, ax02 = plt.subplots(figsize=(16, 10))
ax02 = sns.boxplot(
    data=df,
    x="activity",
    y="loan_amount"
)

# %% [markdown]
# #### Reflection

# %% [markdown]
# On average, "Farming" receives the largest loan amount and also has the widest distribution.

# %% [markdown]
# I can use nearly identical syntax (as I have used for box plots) to create violin plots. Take this line of code from above:
#
# ```python
# sns.boxplot(data=df, x="activity", y="loan_amount")
# ```
#
# To visualize the distribution of the exact same data as a violin plot I could pass the same parameters to `sns.violinplot()` instead of `sns.boxplot()`.

# %%
f02, ax02 = plt.subplots(figsize=(16, 10))
ax02 = sns.violinplot(
    data=df,
    x="activity",
    y="loan_amount"
)

# %% [markdown]
# ### Create a violin plot that visualizes the distribution of loan amount by country.
# Previously, I created a violin plot and plotted the data by _activity_. This time, create a violin plot that plots the data by _country_.
# <!-- <br>
# <details>
# <summary>Hint</summary>
# <br>
# Change the value of the `x` argument passed into the `violinplot()` function.
# <br>
# </details> -->

# %%
f02, ax02 = plt.subplots(figsize=(16, 10))
ax02 = sns.violinplot(
    data=df,
    x="country",
    y="loan_amount"
)

# %% [markdown]
# ## Step 10: Split Violin Plots

# %% [markdown]
# Use the `hue` and `split` parameters with `sns.violinplot()` to visualize the distribution of loan amount by country, split by gender.
# <!--
# <br>
# <details>
# <summary>Hint</summary>
# <br>
# The argument `hue` should be set to `"gender"` and `split` should equal `True`.
# <br>
# </details> -->

# %%
# Some styling
sns.set_palette("Spectral")

f02, ax02 = plt.subplots(figsize=(16, 10))
ax02 = sns.violinplot(
    data=df,
    x="country",
    y="loan_amount",
    hue = "gender",
    split = True
)

# %% [markdown]
# #### Reflection

# %% [markdown]
# In Pakistan, the average loan amount received by women is much less than the average loan amount received by men.
# The same can be said for Cambodia (more or less).
# In El Salvador, there is a fairly equal distribution of loans (total number of loans) between genders, as well as
# similar median loan amounts (on average).
